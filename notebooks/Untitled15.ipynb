# %% [markdown]
# <a href="https://colab.research.google.com/github/anokh-surpur/Society_sim/blob/main/notebooks/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/anokh-surpur/Society_sim/blob/main/notebooks/simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install deps (Colab only)
# !pip install google-generativeai networkx matplotlib pandas

import os
from src.simulation import RumorSimulation

# 1. Set Gemini API key
API_KEY = "AIzaSyD6cpR3jLSqDNFGYT3JGlwQ8uH-aBKQPu8"   # store safely

# 2. Define rumor (you can toggle truth/false)
rumor = "Drinking turmeric milk cures COVID."
truth_label = False  # it's false

# 3. Run simulation
sim = RumorSimulation(api_key=API_KEY, rumor=rumor, truth_label=truth_label)
df = sim.run(steps=5)
df.head()
